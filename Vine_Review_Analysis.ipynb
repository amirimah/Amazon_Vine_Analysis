# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("vine_table.csv")

# %%
helpful_df= df[df["total_votes"]>= 20]
helpful_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 73       RL8D0KJ0J9L0O            5            152          165    N
# 157     R1BEINAIQFBRJC            5             21           23    N
# 190     R2L59KIJH302P9            4             26           26    N
# 221      RR99CPG695T0I            5            215          248    N
# 237     R1XQNKKUPCMWVO            5             43           44    N
# ...                ...          ...            ...          ...  ...
# 792079  R1HWY1Z29N8XUU            4             29           30    N
# 792086  R1OBNEXHLWO188            5             59           59    N
# 792091   R3A76JWPT014A            5             31           35    N
# 792101   R15YY6Z5KN7F9            5             44           45    N
# 792108  R1F7BNIK2R72ZC            5             21           21    N
#
#        verified_purchase
# 73                     Y
# 157                    Y
# 190                    Y
# 221                    N
# ...

# %%
vine_df = helpful_df[(helpful_df["helpful_votes"]/helpful_df["total_votes"]>=0.5) & (helpful_df["vine"]=="Y")]
vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 5408    R2BQOD1R0228FN            3             17           26    Y
# 8246     RC31RUPFOHBHQ            4            102          117    Y
# 12219    REN3N1WITLF1Y            5             33           37    Y
# 13330    R71RZQ9UZVG47            4             38           47    Y
# 16942   R38NMQBH88HLM6            4             18           24    Y
# ...                ...          ...            ...          ...  ...
# 763326  R2QLL1VI9MRY2W            4            768          783    Y
# 763464  R15S9ONTV908AJ            4             21           24    Y
# 763976  R3E85BMKO2AWUP            4            155          177    Y
# 764209   RGNC5HFA9IZ5V            5             59           63    Y
# 764564  R142W0FDRAM7WE            5             99          111    Y
#
#        verified_purchase
# 5408                   N
# 8246                   N
# 12219                  N
# 13330                  N
# ...

# %%
not_vine_df = helpful_df[(helpful_df["helpful_votes"]/helpful_df["total_votes"]>=0.5) & (helpful_df["vine"]=="N")]
not_vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 73       RL8D0KJ0J9L0O            5            152          165    N
# 157     R1BEINAIQFBRJC            5             21           23    N
# 190     R2L59KIJH302P9            4             26           26    N
# 221      RR99CPG695T0I            5            215          248    N
# 237     R1XQNKKUPCMWVO            5             43           44    N
# ...                ...          ...            ...          ...  ...
# 792079  R1HWY1Z29N8XUU            4             29           30    N
# 792086  R1OBNEXHLWO188            5             59           59    N
# 792091   R3A76JWPT014A            5             31           35    N
# 792101   R15YY6Z5KN7F9            5             44           45    N
# 792108  R1F7BNIK2R72ZC            5             21           21    N
#
#        verified_purchase
# 73                     Y
# 157                    Y
# 190                    Y
# 221                    N
# ...

# %% [markdown]
# ### total number of reviews, the number of 5-star reviews, and the percentage 5-star reviews

# %%
five_star_Y=vine_df[vine_df['star_rating']==5]
five_star_Y = five_star_Y['review_id'].count()
five_star_Y
# Out:
# 74

# %%
five_star_N=not_vine_df[not_vine_df['star_rating']==5]
five_star_N= five_star_N['review_id'].count()
five_star_N
# Out:
# 8482

# %%
total_reviews_Y = vine_df['review_id'].count()
total_reviews_Y
# Out:
# 136

# %%
total_reviews_N = not_vine_df['review_id'].count()
total_reviews_N
# Out:
# 18019

# %%
percentage_five_star_Y = (five_star_Y/total_reviews_Y)*100
percentage_five_star_Y
# Out:
# 54.41176470588235

# %%
percentage_five_star_N = (five_star_N/total_reviews_N)*100
percentage_five_star_N
# Out:
# 47.072534546867196
